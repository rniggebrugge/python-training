# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
ticker = "MSFT"
df = yf.download(ticker, start="2017-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
d1 = df["Close"].diff()
d2 = df["Close"].diff().diff()
df["d1"]=d1
df["d2"]=d2

# %%
df = df.dropna().copy()

# %%
df
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            MSFT        MSFT        MSFT        MSFT        MSFT
# Date
# 2017-01-05   56.460869   62.299999   62.660000   62.029999   62.189999
# 2017-01-06   56.950237   62.840000   63.150002   62.040001   62.299999
# 2017-01-09   56.768993   62.639999   63.080002   62.540001   62.759998
# 2017-01-10   56.750866   62.619999   63.070000   62.279999   62.730000
# 2017-01-11   57.267456   63.189999   63.230000   62.430000   62.610001
# ...                ...         ...         ...         ...         ...
# 2024-11-20  414.659973  415.489990  417.290009  410.579987  416.869995
# 2024-11-21  412.869995  412.869995  419.779999  410.290009  419.500000
# 2024-11-22  417.000000  417.000000  417.399994  411.059998  411.369995
# 2024-11-25  418.790009  418.790009  421.079987  414.850006  418.380005
# 2024-11-26  424.082794  424.082794  425.290009  418.929993  419.584991
#
# Price         Volume        d1        d2
# Ticker          MSFT
# Date
# 2017-01-05  24876000  0.000000  0.280003
# 2017-01-06  19922900  0.540001  0.540001
# 2017-01-09  20382700 -0.200001 -0.740002
# 2017-01-10  18593000 -0.020000  0.180000
# 2017-01-11  21517300  0.570000  0.590000
# ...              ...       ...       ...
# 2024-11-20  19191700 -2.300018 -4.330017
# 2024-11-21  20780200 -2.619995 -0.319977
# 2024-11-22  24814600  4.130005  6.750000
# 2024-11-25  27651300  1.790009 -2.339996
# 2024-11-26   6389968  5.292786  3.502777
#
# [1987 rows x 8 columns]

# %%
df = df.apply(lambda x: (x  / x.max() ))

# %%
df
# Out:
# Price      Adj Close     Close      High       Low      Open    Volume  \
# Ticker          MSFT      MSFT      MSFT      MSFT      MSFT      MSFT
# Date
# 2017-01-05  0.121216  0.133245  0.133789  0.133553  0.133169  0.223620
# 2017-01-06  0.122267  0.134400  0.134835  0.133574  0.133405  0.179095
# 2017-01-09  0.121878  0.133972  0.134686  0.134651  0.134390  0.183228
# 2017-01-10  0.121839  0.133929  0.134664  0.134091  0.134325  0.167140
# 2017-01-11  0.122948  0.135148  0.135006  0.134414  0.134069  0.193428
# ...              ...       ...       ...       ...       ...       ...
# 2024-11-20  0.890236  0.888635  0.890979  0.883994  0.892655  0.172522
# 2024-11-21  0.886393  0.883031  0.896295  0.883370  0.898287  0.186802
# 2024-11-22  0.895260  0.891864  0.891214  0.885028  0.880878  0.223068
# 2024-11-25  0.899103  0.895693  0.899071  0.893188  0.895889  0.248569
# 2024-11-26  0.910466  0.907013  0.908060  0.901972  0.898469  0.057442
#
# Price             d1        d2
# Ticker
# Date
# 2017-01-05  0.000000  0.008102
# 2017-01-06  0.027068  0.015625
# 2017-01-09 -0.010025 -0.021412
# 2017-01-10 -0.001003  0.005208
# 2017-01-11  0.028571  0.017072
# ...              ...       ...
# 2024-11-20 -0.115289 -0.125290
# 2024-11-21 -0.131328 -0.009259
# 2024-11-22  0.207018  0.195312
# 2024-11-25  0.089725 -0.067708
# 2024-11-26  0.265303  0.101353
#
# [1987 rows x 8 columns]

# %%
df[["d1","d2"]].plot()
# Out:
# <Axes: xlabel='Date'>
