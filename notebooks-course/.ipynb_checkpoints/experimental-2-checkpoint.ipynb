# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
ticker = 'MSFT'
df = yf.download(ticker)
df.index = pd.to_datetime(df.index)
# df.drop(columns="Adj Close", inplace=True)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.059946    0.097222    0.101563    0.088542
# 1986-03-14 00:00:00+00:00    0.062087    0.100694    0.102431    0.097222
# 1986-03-17 00:00:00+00:00    0.063158    0.102431    0.103299    0.100694
# 1986-03-18 00:00:00+00:00    0.061552    0.099826    0.103299    0.098958
# 1986-03-19 00:00:00+00:00    0.060482    0.098090    0.100694    0.097222
# ...                               ...         ...         ...         ...
# 2024-11-07 00:00:00+00:00  425.429993  425.429993  426.850006  419.880005
# 2024-11-08 00:00:00+00:00  422.540009  422.540009  426.500000  421.779999
# 2024-11-11 00:00:00+00:00  418.010010  418.010010  424.809998  416.000000
# 2024-11-12 00:00:00+00:00  423.029999  423.029999  424.440002  417.200012
# 2024-11-13 00:00:00+00:00  425.200012  425.200012  429.329987  418.209991
#
# Price                            Open      Volume
# Ticker                           MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.088542  1031788800
# 1986-03-14 00:00:00+00:00    0.097222   308160000
# 1986-03-17 00:00:00+00:00    0.100694   133171200
# 1986-03-18 00:00:00+00:00    0.102431    67766400
# 1986-03-19 00:00:00+00:00    0.099826    47894400
# ...                               ...         ...
# 2024-11-07 00:00:00+00:00  421.279999    19901800
# 2024-11-08 00:00:00+00:00  425.320007    16891400
# 2024-11-11 00:00:00+00:00  422.519989    24503300
# 2024-11-12 00:00:00+00:00  418.250000    19401200
# 2024-11-13 00:00:00+00:00  421.640015    21477900
#
# [9747 rows x 6 columns]

# %%
df["change_tomorrow"] = df["Close"].pct_change(-1)*100
df = df.dropna().copy()
df
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.059946    0.097222    0.101563    0.088542
# 1986-03-14 00:00:00+00:00    0.062087    0.100694    0.102431    0.097222
# 1986-03-17 00:00:00+00:00    0.063158    0.102431    0.103299    0.100694
# 1986-03-18 00:00:00+00:00    0.061552    0.099826    0.103299    0.098958
# 1986-03-19 00:00:00+00:00    0.060482    0.098090    0.100694    0.097222
# ...                               ...         ...         ...         ...
# 2024-11-06 00:00:00+00:00  420.179993  420.179993  420.450012  410.519989
# 2024-11-07 00:00:00+00:00  425.429993  425.429993  426.850006  419.880005
# 2024-11-08 00:00:00+00:00  422.540009  422.540009  426.500000  421.779999
# 2024-11-11 00:00:00+00:00  418.010010  418.010010  424.809998  416.000000
# 2024-11-12 00:00:00+00:00  423.029999  423.029999  424.440002  417.200012
#
# Price                            Open      Volume change_tomorrow
# Ticker                           MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.088542  1031788800       -3.448071
# 1986-03-14 00:00:00+00:00    0.097222   308160000       -1.695774
# 1986-03-17 00:00:00+00:00    0.100694   133171200        2.609539
# 1986-03-18 00:00:00+00:00    0.102431    67766400        1.769803
# 1986-03-19 00:00:00+00:00    0.099826    47894400        2.727102
# ...                               ...         ...             ...
# 2024-11-06 00:00:00+00:00  412.420013    26681800       -1.234046
# 2024-11-07 00:00:00+00:00  421.279999    19901800        0.683955
# 2024-11-08 00:00:00+00:00  425.320007    16891400        1.083706
# 2024-11-11 00:00:00+00:00  422.519989    24503300       -1.186674
# 2024-11-12 00:00:00+00:00  418.250000    19401200       -0.510351
#
# [9746 rows x 7 columns]

# %%
df["change_tomorrow_direction"] = df.change_tomorrow.apply(lambda v: "UP" if v>0 else "DOWN")
df
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.059946    0.097222    0.101563    0.088542
# 1986-03-14 00:00:00+00:00    0.062087    0.100694    0.102431    0.097222
# 1986-03-17 00:00:00+00:00    0.063158    0.102431    0.103299    0.100694
# 1986-03-18 00:00:00+00:00    0.061552    0.099826    0.103299    0.098958
# 1986-03-19 00:00:00+00:00    0.060482    0.098090    0.100694    0.097222
# ...                               ...         ...         ...         ...
# 2024-11-06 00:00:00+00:00  420.179993  420.179993  420.450012  410.519989
# 2024-11-07 00:00:00+00:00  425.429993  425.429993  426.850006  419.880005
# 2024-11-08 00:00:00+00:00  422.540009  422.540009  426.500000  421.779999
# 2024-11-11 00:00:00+00:00  418.010010  418.010010  424.809998  416.000000
# 2024-11-12 00:00:00+00:00  423.029999  423.029999  424.440002  417.200012
#
# Price                            Open      Volume change_tomorrow  \
# Ticker                           MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.088542  1031788800       -3.448071
# 1986-03-14 00:00:00+00:00    0.097222   308160000       -1.695774
# 1986-03-17 00:00:00+00:00    0.100694   133171200        2.609539
# 1986-03-18 00:00:00+00:00    0.102431    67766400        1.769803
# 1986-03-19 00:00:00+00:00    0.099826    47894400        2.727102
# ...                               ...         ...             ...
# 2024-11-06 00:00:00+00:00  412.420013    26681800       -1.234046
# 2024-11-07 00:00:00+00:00  421.279999    19901800        0.683955
# 2024-11-08 00:00:00+00:00  425.320007    16891400        1.083706
# 2024-11-11 00:00:00+00:00  422.519989    24503300       -1.186674
# 2024-11-12 00:00:00+00:00  418.250000    19401200       -0.510351
#
# Price                     change_tomorrow_direction
# Ticker
# Date
# 1986-03-13 00:00:00+00:00                      DOWN
# 1986-03-14 00:00:00+00:00                      DOWN
# 1986-03-17 00:00:00+00:00                        UP
# 1986-03-18 00:00:00+00:00                        UP
# 1986-03-19 00:00:00+00:00                        UP
# ...                                             ...
# 2024-11-06 00:00:00+00:00                      DOWN
# 2024-11-07 00:00:00+00:00                        UP
# 2024-11-08 00:00:00+00:00                        UP
# 2024-11-11 00:00:00+00:00                      DOWN
# 2024-11-12 00:00:00+00:00                      DOWN
#
# [9746 rows x 8 columns]

# %%
dftrain = df.loc["2010-01-01":"2022-12-13",:].copy().drop(columns=["change_tomorrow","change_tomorrow_direction"])
dftest =  df.loc["2023-01-01":,:].copy().drop(columns=["change_tomorrow","change_tomorrow_direction"])

# %%
ttrain = df.loc["2010-01-01":"2022-12-13","change_tomorrow_direction"].copy()
ttest  = df.loc["2023-01-01":,"change_tomorrow_direction"].copy()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_dt = DecisionTreeClassifier(max_depth=6)
model_dt.fit(X=dftrain, y=ttrain)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
from sklearn.tree import plot_tree
#plot_tree(decision_tree=model_dt);

# %%
ptrain = model_dt.predict(X=dftrain)
ptest = model_dt.predict(X=dftest)

# %%
Vtrain = (ptrain == ttrain).sum()/len(ptrain)
Vtest = (ptest == ttest).sum()/len(ptest)

# %%
print(f"Success rate train = {Vtrain}\nSuccess rate test  = {Vtest}")
# Out:
# Success rate train = 0.5687116564417178
# Success rate test  = 0.4989339019189765

# %%
from backtesting import Backtest, Strategy

# %%
already_bought = False
list_buy_sell = []
for d in ttrain:
    if d=='UP' and already_bought == False:
        list_buy_sell.append(1)
        already_bought = True
    elif d=='DOWN' and already_bought == True:
        list_buy_sell.append(-1)
        already_bought = False
    else:
        list_buy_sell.append(0)

# %%
track = pd.DataFrame({"direction":ttrain, "buy_sell":list_buy_sell})
track
# Out:
#                           direction  buy_sell
# Date
# 2010-01-04 00:00:00+00:00      DOWN         0
# 2010-01-05 00:00:00+00:00        UP         1
# 2010-01-06 00:00:00+00:00        UP         0
# 2010-01-07 00:00:00+00:00      DOWN        -1
# 2010-01-08 00:00:00+00:00        UP         1
# ...                             ...       ...
# 2022-12-07 00:00:00+00:00      DOWN        -1
# 2022-12-08 00:00:00+00:00        UP         1
# 2022-12-09 00:00:00+00:00      DOWN        -1
# 2022-12-12 00:00:00+00:00      DOWN         0
# 2022-12-13 00:00:00+00:00      DOWN         0
#
# [3260 rows x 2 columns]

# %%
class ClassificationUP(Strategy):
    def init(self):
        self.model = model_dt
        self.already_bought = False

    def next(self):
        explanatory_today = self.data.df.iloc[[-1],:]
        forecast_tomorrow = self.model.predict(explanatory_today)[0]

        if forecast_tomorrow == 'UP' and self.already_bought == False:
            self.buy()
            self.already_bought = True
        elif forecast_tomorrow == 'DOWN' and self.already_bought == True:
            self.sell()
            self.already_bought = False
        else:
            pass

# %%
bt = Backtest(data=dftrain, strategy=ClassificationUP, cash=10000, commission=.002, exclusive_orders=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:3619, in MultiIndex._convert_can_do_setop(self, other)
#    3618 try:
# -> 3619     other = MultiIndex.from_tuples(other, names=self.names)
#    3620 except (ValueError, TypeError) as err:
#    3621     # ValueError raised by tuples_to_object_array if we
#    3622     #  have non-object dtype
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:211, in names_compat.<locals>.new_meth(self_or_cls, *args, **kwargs)
#     209     kwargs["names"] = kwargs.pop("name")
# --> 211 return meth(self_or_cls, *args, **kwargs)
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:597, in MultiIndex.from_tuples(cls, tuples, sortorder, names)
#     595     arrays = cast(List[Sequence[Hashable]], arrs)
# --> 597 return cls.from_arrays(arrays, sortorder=sortorder, names=names)
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:510, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     508     names = [getattr(arr, "name", None) for arr in arrays]
# --> 510 return cls(
#     511     levels=levels,
#     512     codes=codes,
#     513     sortorder=sortorder,
#     514     names=names,
#     515     verify_integrity=False,
#     516 )
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:345, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     343 if names is not None:
#     344     # handles name validation
# --> 345     result._set_names(names)
#     347 if sortorder is not None:
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:1433, in MultiIndex._set_names(self, names, level, validate)
#    1432     if level is None and len(names) != self.nlevels:
# -> 1433         raise ValueError(
#    1434             "Length of names must match number of levels in MultiIndex."
#    1435         )
#    1437 if level is None:
#
# ValueError: Length of names must match number of levels in MultiIndex.
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 bt = Backtest(data=dftrain, strategy=ClassificationUP, cash=10000, commission=.002, exclusive_orders=True)
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/backtesting/backtesting.py:1066, in Backtest.__init__(self, data, strategy, cash, commission, margin, trade_on_close, hedging, exclusive_orders)
#    1064 if len(data) == 0:
#    1065     raise ValueError('OHLC `data` is empty')
# -> 1066 if len(data.columns.intersection({'Open', 'High', 'Low', 'Close', 'Volume'})) != 5:
#    1067     raise ValueError("`data` must be a pandas.DataFrame with columns "
#    1068                      "'Open', 'High', 'Low', 'Close', and (optionally) 'Volume'")
#    1069 if data[['Open', 'High', 'Low', 'Close']].isnull().values.any():
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py:3323, in Index.intersection(self, other, sort)
#    3321 self._validate_sort_keyword(sort)
#    3322 self._assert_can_do_setop(other)
# -> 3323 other, result_name = self._convert_can_do_setop(other)
#    3325 if not is_dtype_equal(self.dtype, other.dtype):
#    3326     self, other = self._dti_setop_align_tzs(other, "intersection")
#
# File ~/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/pandas/core/indexes/multi.py:3623, in MultiIndex._convert_can_do_setop(self, other)
#    3619             other = MultiIndex.from_tuples(other, names=self.names)
#    3620         except (ValueError, TypeError) as err:
#    3621             # ValueError raised by tuples_to_object_array if we
#    3622             #  have non-object dtype
# -> 3623             raise TypeError(msg) from err
#    3624 else:
#    3625     result_names = get_unanimous_names(self, other)
#
# TypeError: other must be a MultiIndex or a list of tuples

# %%
dftrain.head()
# Out:
# Price                      Adj Close      Close       High        Low  \
# Ticker                          MSFT       MSFT       MSFT       MSFT
# Date
# 2010-01-04 00:00:00+00:00  23.347322  30.950001  31.100000  30.590000
# 2010-01-05 00:00:00+00:00  23.354856  30.959999  31.100000  30.639999
# 2010-01-06 00:00:00+00:00  23.211535  30.770000  31.080000  30.520000
# 2010-01-07 00:00:00+00:00  22.970146  30.450001  30.700001  30.190001
# 2010-01-08 00:00:00+00:00  23.128555  30.660000  30.879999  30.240000
#
# Price                           Open    Volume
# Ticker                          MSFT      MSFT
# Date
# 2010-01-04 00:00:00+00:00  30.620001  38409100
# 2010-01-05 00:00:00+00:00  30.850000  49749600
# 2010-01-06 00:00:00+00:00  30.879999  58182400
# 2010-01-07 00:00:00+00:00  30.629999  50559700
# 2010-01-08 00:00:00+00:00  30.280001  51197400
