# %%
import yfinance as yf

# %%
ticker = "hpq"
df = yf.download(ticker)
df = df.loc["2020-01-01":,:]
df = df.droplevel('Ticker', axis=1)
df["change_tomorrow"]=df.Close.pct_change(-1)*(-100)
df = df.dropna()
df.Close.plot()
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Date
# 2020-01-02 00:00:00+00:00  17.808582  20.790001  20.830000  20.650000
# 2020-01-03 00:00:00+00:00  17.585861  20.530001  20.680000  20.450001
# 2020-01-06 00:00:00+00:00  17.654392  20.610001  20.790001  20.510000
# 2020-01-07 00:00:00+00:00  17.697216  20.660000  20.780001  20.510000
# 2020-01-08 00:00:00+00:00  17.928503  20.930000  20.990000  20.530001
# ...                              ...        ...        ...        ...
# 2024-11-21 00:00:00+00:00  37.910000  37.910000  37.959999  36.730000
# 2024-11-22 00:00:00+00:00  38.130001  38.130001  38.650002  37.880001
# 2024-11-25 00:00:00+00:00  39.299999  39.299999  39.799999  38.220001
# 2024-11-26 00:00:00+00:00  39.099998  39.099998  39.619999  38.939999
# 2024-11-27 00:00:00+00:00  34.660000  34.660000  37.500000  33.529999
#
# Price                           Open    Volume  change_tomorrow
# Date
# 2020-01-02 00:00:00+00:00  20.680000   7194700        -1.266440
# 2020-01-03 00:00:00+00:00  20.480000   5421800         0.388161
# 2020-01-06 00:00:00+00:00  20.660000   9312500         0.242010
# 2020-01-07 00:00:00+00:00  20.559999   6536200         1.290017
# 2020-01-08 00:00:00+00:00  20.530001   7780100         1.459508
# ...                              ...       ...              ...
# 2024-11-21 00:00:00+00:00  36.770000   5969400         0.576977
# 2024-11-22 00:00:00+00:00  37.959999   6961100         2.977095
# 2024-11-25 00:00:00+00:00  38.490002  14160200        -0.511511
# 2024-11-26 00:00:00+00:00  39.250000  12112400       -12.810152
# 2024-11-27 00:00:00+00:00  36.560001  27423800         2.173301
#
# [1236 rows x 7 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
model_dt = DecisionTreeRegressor(max_depth=25, random_state=42)
model_ab = AdaBoostRegressor()

# %%
from backtesting import Backtest, Strategy

# %%
class Regression(Strategy):
    print("START")
    limit_buy = 0
    limit_sell = -3
    n_train_factor = 1
    n_train = 2
    coef_retrain = 1
    model = None
    
    def init(self):
        self.predictions = []
        self.already_bought = False
        self.model = Regression.model
        
        X_train = self.data.df.iloc[:self.n_train, :-1]
        y_train = self.data.df.iloc[:self.n_train, -1]
        
        self.model.fit(X=X_train, y=y_train)

    def next(self):
        explanatory_today = self.data.df.iloc[[-1], :-1]
        actual = self.data.df.iloc[[-1],-1][0]
        forecast_tomorrow = self.model.predict(explanatory_today)[0]
        self.predictions.append(forecast_tomorrow)
        global PREDICTIONS
        PREDICTIONS.append([actual, forecast_tomorrow ])
        # print(f"predict for {explanatory_today.index} ")
        
        if forecast_tomorrow > self.limit_buy and self.already_bought == False:
            self.buy()
            self.already_bought = True
        elif forecast_tomorrow < self.limit_sell and self.already_bought == True:
            self.sell()
            self.already_bought = False
        else:
            pass



class WalkForwardAnchored(Regression):
    def next(self):
        
        # we don't take any action and move on to the following day
        if len(self.data) < (self.n_train*self.n_train_factor):
            return
        
        # we retrain the model each 200 days
        if len(self.data) % self.coef_retrain == 0:
            X_train = self.data.df.iloc[:-1, :-1]
            y_train = self.data.df.iloc[:-1, -1]
            # print(f"Train start {X_train.index[0]}, train end {X_train.index[-1]}")

            self.model.fit(X_train, y_train)

            super().next()
            
        else:
            
            super().next()

    def __del__(self):
        print(self.predictions)            
            
class WalkForwardUnanchored(Regression):
    def next(self):
        
        # we don't take any action and move on to the following day
        if len(self.data) < (self.n_train*self.n_train_factor):
            return
        
        # we retrain the model each 200 days
        if len(self.data) % self.coef_retrain == 0:
            X_train = self.data.df.iloc[-(self.n_train*self.n_train_factor):-1, :-1]
            y_train = self.data.df.iloc[-(self.n_train*self.n_train_factor):-1, -1]
            # print(f"Train start {X_train.index[0]}, train end {X_train.index[-1]}")

            self.model.fit(X_train, y_train)

            super().next()
            
        else:
            
            super().next()
# Out:
# START

# %%
Regression.model = model_dt

# %%
bt_anchored = Backtest(df, WalkForwardAnchored, cash=20000, commission=.002, exclusive_orders=True)
bt_unAnchored = Backtest(df, WalkForwardUnanchored, cash=20000, commission=.002, exclusive_orders=True)

# %%
import multiprocessing as mp
try:
  mp.set_start_method('fork')
except:
  pass

# %%
PREDICTIONS = []
bt_anchored.run()
# Out:
# Start                     2020-01-02 00:00...
# End                       2024-11-27 00:00...
# Duration                   1791 days 00:00:00
# Exposure Time [%]                   99.676375
# Equity Final [$]                  37952.97157
# Equity Peak [$]                  48356.972003
# Return [%]                          89.764858
# Buy & Hold Return [%]               66.714759
# Return (Ann.) [%]                   13.952434
# Volatility (Ann.) [%]               43.649091
# Sharpe Ratio                          0.31965
# Sortino Ratio                        0.541898
# Calmar Ratio                         0.420479
# Max. Drawdown [%]                  -33.182272
# Avg. Drawdown [%]                   -7.921156
# Max. Drawdown Duration      343 days 00:00:00
# Avg. Drawdown Duration       62 days 00:00:00
# # Trades                                  185
# Win Rate [%]                        50.810811
# Best Trade [%]                      29.129346
# Worst Trade [%]                    -15.691642
# Avg. Trade [%]                       0.347058
# Max. Trade Duration          71 days 00:00:00
# Avg. Trade Duration          10 days 00:00:00
# Profit Factor                        1.303481
# Expectancy [%]                       0.498104
# SQN                                  0.851609
# _strategy                 WalkForwardAnchored
# _equity_curve                             ...
# _trades                        Size  Entry...
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
def plotdata(data):
  x = [row[0] for row in data]
  y = [row[1] for row in data]
  colors = ['blue' if xi*yi>=0 else 'red' for  xi, yi in zip(x,y)]
  plt.scatter(x,y, color=colors, alpha=.3)

# %%
df.loc["2020-10-16"]
# Out:
# Price
# Adj Close          1.727036e+01
# Close              1.960000e+01
# High               1.982000e+01
# Low                1.959000e+01
# Open               1.962000e+01
# Volume             7.409100e+06
# change_tomorrow   -1.239668e+00
# Name: 2020-10-16 00:00:00+00:00, dtype: float64

# %%
stats_skopt, heatmap, optimize_result = bt_anchored.optimize(
    limit_buy = range(0, 4), limit_sell = range(-5, 0), #n_train_factor = range(1,6),
    maximize='Return [%]',
    max_tries=500,
    random_state=42,
    return_heatmap=True,
    return_optimization=True,
    method='skopt'
    )

dff = heatmap.reset_index()
dff = dff.sort_values('Return [%]', ascending=False)
dff
# Out:
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [2, -5]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [1, -2]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [0, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [2, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [0, -5]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [2, -4]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [3, -2]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, -3] before, using random point [0, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -4] before, using random point [1, -4]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [2, -3] before, using random point [1, -4]
#   warnings.warn(
#     limit_buy  limit_sell  Return [%]
# 1           0          -4  124.173822
# 11          2          -3   99.177592
# 6           1          -3   80.489550
# 4           1          -5   77.573695
# 9           2          -5   64.305118
# 0           0          -5   63.561493
# 5           1          -4   37.754591
# 2           0          -2   34.924694
# 10          2          -4   27.762352
# 12          2          -2   16.643176
# 14          3          -5    8.698452
# 16          3          -3    0.050287
# 13          2          -1   -3.667519
# 8           1          -1   -4.263236
# 17          3          -2   -6.242806
# 7           1          -2  -11.263761
# 15          3          -4  -27.113566
# 18          3          -1  -38.162368
# 3           0          -1  -39.448317

# %%
stats_skopt, heatmap, optimize_result = bt_unAnchored.optimize(
    limit_buy = range(0, 4), limit_sell = range(-5, 0), n_train_factor = range(1,6),
    maximize='Return [%]',
    max_tries=500,
    random_state=42,
    return_heatmap=True,
    return_optimization=True,
    method='skopt'
    )

dff = heatmap.reset_index()
dff = dff.sort_values('Return [%]', ascending=False)
dff
# Out:
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -5] before, using random point [2, -5]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -5] before, using random point [1, -2]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [0, -5] before, using random point [0, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [2, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [0, -5]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [2, -4]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [3, -2]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [0, -1]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [1, -4]
#   warnings.warn(
# /home/remco/PythonDocuments/practical-python-for-algorithmic-trading-4403633/venv/lib/python3.8/site-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [1, -5] before, using random point [1, -4]
#   warnings.warn(
#     limit_buy  limit_sell  Return [%]
# 0           0          -5   96.136545
# 4           1          -5   87.671174
# 9           2          -5   84.045262
# 14          3          -5   55.561405
# 10          2          -4   44.640397
# 17          3          -2   44.414595
# 1           0          -4   42.212150
# 16          3          -3   27.707286
# 11          2          -3   18.362301
# 5           1          -4   11.847228
# 15          3          -4    4.671172
# 6           1          -3  -21.884212
# 12          2          -2  -25.111313
# 18          3          -1  -32.799072
# 7           1          -2  -43.579872
# 2           0          -2  -44.746876
# 3           0          -1  -65.549897
# 13          2          -1  -67.941112
# 8           1          -1  -68.924260

# %%
bt_anchored.plot(filename="reports_backtesting/10E_anchored.html")
bt_unAnchored.plot(filename="reports_backtesting/10E_UNanchored.html")
# Out:
# Row(id='6501', ...)

# %%
PREDICTIONS = []
bt_unAnchored.run(n_train_factor = 3, limit_buy = 0, limit_sell=-5)
# Out:
# Start                     2020-01-02 00:00...
# End                       2024-11-26 00:00...
# Duration                   1790 days 00:00:00
# Exposure Time [%]                   51.093117
# Equity Final [$]                 21666.533902
# Equity Peak [$]                    24425.0313
# Return [%]                            8.33267
# Buy & Hold Return [%]               88.071172
# Return (Ann.) [%]                    1.646544
# Volatility (Ann.) [%]               22.651797
# Sharpe Ratio                         0.072689
# Sortino Ratio                        0.109846
# Calmar Ratio                         0.047459
# Max. Drawdown [%]                  -34.694188
# Avg. Drawdown [%]                   -31.08955
# Max. Drawdown Duration      722 days 00:00:00
# Avg. Drawdown Duration      451 days 00:00:00
# # Trades                                   18
# Win Rate [%]                        55.555556
# Best Trade [%]                      19.896731
# Worst Trade [%]                    -23.382624
# Avg. Trade [%]                       0.445751
# Max. Trade Duration         162 days 00:00:00
# Avg. Trade Duration          51 days 00:00:00
# Profit Factor                        1.312563
# Expectancy [%]                       0.907172
# SQN                                  0.192398
# _strategy                 WalkForwardUnanc...
# _equity_curve                             ...
# _trades                       Size  EntryB...
# dtype: object

# %%
plotdata(PREDICTIONS)

# %%
a=[1 if d[0]*d[1]>=0 else -1 for d in PREDICTIONS]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[170], line 2
#       1 a=[1 if d[0]*d[1]>=0 else -1 for d in PREDICTIONS]
# ----> 2 a.sum()
#
# AttributeError: 'list' object has no attribute 'sum'
