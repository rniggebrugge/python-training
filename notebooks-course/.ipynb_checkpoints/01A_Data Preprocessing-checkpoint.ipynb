# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Download & export data tables

# %% [markdown]
# ### Download Microsoft OHLCV with `yfinance` library

# %% [markdown]
# **Search for the ticker code**
#
# YFinance: https://finance.yahoo.com/
#
# - [ ] Microsoft: ???

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ### Download any ticker

# %% [markdown]
# - [x] Microsoft: MSFT
# - [ ] Bitcoin: ???

# %%
ticker = 'MSFT'
df = yf.download(ticker)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           MSFT        MSFT        MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.059946    0.097222    0.101563    0.088542
# 1986-03-14 00:00:00+00:00    0.062087    0.100694    0.102431    0.097222
# 1986-03-17 00:00:00+00:00    0.063158    0.102431    0.103299    0.100694
# 1986-03-18 00:00:00+00:00    0.061552    0.099826    0.103299    0.098958
# 1986-03-19 00:00:00+00:00    0.060482    0.098090    0.100694    0.097222
# ...                               ...         ...         ...         ...
# 2024-11-05 00:00:00+00:00  411.459991  411.459991  414.899994  408.079987
# 2024-11-06 00:00:00+00:00  420.179993  420.179993  420.450012  410.519989
# 2024-11-07 00:00:00+00:00  425.429993  425.429993  426.850006  419.880005
# 2024-11-08 00:00:00+00:00  422.540009  422.540009  426.500000  421.779999
# 2024-11-11 00:00:00+00:00  418.819702  418.819702  424.809998  416.000000
#
# Price                            Open      Volume
# Ticker                           MSFT        MSFT
# Date
# 1986-03-13 00:00:00+00:00    0.088542  1031788800
# 1986-03-14 00:00:00+00:00    0.097222   308160000
# 1986-03-17 00:00:00+00:00    0.100694   133171200
# 1986-03-18 00:00:00+00:00    0.102431    67766400
# 1986-03-19 00:00:00+00:00    0.099826    47894400
# ...                               ...         ...
# 2024-11-05 00:00:00+00:00  408.369995    17626000
# 2024-11-06 00:00:00+00:00  412.420013    26681800
# 2024-11-07 00:00:00+00:00  421.279999    19901800
# 2024-11-08 00:00:00+00:00  425.320007    16875500
# 2024-11-11 00:00:00+00:00  422.565002     8304528
#
# [9745 rows x 6 columns]

# %% [markdown]
# ## Visualize the data with plotly
#
# https://plotly.com/python/candlestick-charts/

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df['Open'].values.flatten(),
    high=df['High'].values.flatten(),
    low=df['Low'].values.flatten(),
    close=df['Close'].values.flatten(),
    increasing=dict(line=dict(color='green')),  # Color for increasing (up) candles
    decreasing=dict(line=dict(color='red'))     # Color for decreasing (down) candles
)])

fig.update_layout(
    title='MSFT Stock Price',
    xaxis_title='Date',
    yaxis_title='Stock Price (USD)',
    yaxis=dict(autorange=True)
)

fig.show()

# %% [markdown]
# ## Export the data

# %% [markdown]
# ### Microsoft data

# %% [markdown]
# #### Drop `Adj Close`
#
# - To not confuse the `Close` and `Adj Close`

# %%
if 'Adj Close' in df.columns: df = df.drop(columns='Adj Close')
df.index = [d.strftime("%Y-%m-%d %H:%M:%S") for d in df.index]

# %%
df.head()
# Out:
# Price                   Close      High       Low      Open      Volume
# Ticker                   MSFT      MSFT      MSFT      MSFT        MSFT
# 1986-03-13 00:00:00  0.097222  0.101563  0.088542  0.088542  1031788800
# 1986-03-14 00:00:00  0.100694  0.102431  0.097222  0.097222   308160000
# 1986-03-17 00:00:00  0.102431  0.103299  0.100694  0.100694   133171200
# 1986-03-18 00:00:00  0.099826  0.103299  0.098958  0.102431    67766400
# 1986-03-19 00:00:00  0.098090  0.100694  0.097222  0.099826    47894400

# %% [markdown]
# #### To Excel
#
# - Create a folder called `data`

# %%
import os
os.makedirs("data", exist_ok=True)

df.to_excel("./data/microsoft-prices.xlsx")

# %% [markdown]
# #### To CSV
#
# - Less size in memory

# %%
df.to_csv("./data/microsoft-prices.csv")

# %% [markdown]
# ### Bitcoin data altogether (step by step)

# %% [markdown]
# #### Define ticker

# %%
ticker = 'MSFT'
ticker
# Out:
# 'MSFT'

# %% [markdown]
# #### Download OLHVC

# %%
df_ticker = yf.download(ticker)
df_ticker.index = [d.strftime("%Y-%m-%d %H:%M:%S") for d in df_ticker.index]
df_ticker
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                 Adj Close       Close        High         Low  \
# Ticker                     MSFT        MSFT        MSFT        MSFT
# 1986-03-13 00:00:00    0.059947    0.097222    0.101563    0.088542
# 1986-03-14 00:00:00    0.062087    0.100694    0.102431    0.097222
# 1986-03-17 00:00:00    0.063158    0.102431    0.103299    0.100694
# 1986-03-18 00:00:00    0.061552    0.099826    0.103299    0.098958
# 1986-03-19 00:00:00    0.060482    0.098090    0.100694    0.097222
# ...                         ...         ...         ...         ...
# 2024-11-05 00:00:00  411.459991  411.459991  414.899994  408.079987
# 2024-11-06 00:00:00  420.179993  420.179993  420.450012  410.519989
# 2024-11-07 00:00:00  425.429993  425.429993  426.850006  419.880005
# 2024-11-08 00:00:00  422.540009  422.540009  426.500000  421.779999
# 2024-11-11 00:00:00  418.720001  418.720001  424.809998  416.000000
#
# Price                      Open      Volume
# Ticker                     MSFT        MSFT
# 1986-03-13 00:00:00    0.088542  1031788800
# 1986-03-14 00:00:00    0.097222   308160000
# 1986-03-17 00:00:00    0.100694   133171200
# 1986-03-18 00:00:00    0.102431    67766400
# 1986-03-19 00:00:00    0.099826    47894400
# ...                         ...         ...
# 2024-11-05 00:00:00  408.369995    17626000
# 2024-11-06 00:00:00  412.420013    26681800
# 2024-11-07 00:00:00  421.279999    19901800
# 2024-11-08 00:00:00  425.320007    16875500
# 2024-11-11 00:00:00  422.565002     8312782
#
# [9745 rows x 6 columns]

# %% [markdown]
# #### Create file path

# %%
file_path = f'data/{ticker}.xlsx'
file_path
# Out:
# 'data/MSFT.xlsx'

# %% [markdown]
# #### Export to Excel

# %%
df_ticker.to_excel(file_path)

# %% [markdown]
# #### Export to CSV

# %%
df_ticker.to_csv(f'data/{ticker}.csv')

# %% [markdown]
# #### Snippet

# %%
ticker = 'TSLA'
df_ticker = yf.download(ticker)
df_ticker.index = [d.strftime("%Y-%m-%d %H:%M:%S") for d in df_ticker.index]
df_ticker.to_excel(f'data/{ticker}.xlsx')
df_ticker.to_csv(f'data/{ticker}.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = df_ticker
fig = go.Figure(data=[go.Candlestick(
    x=df.index,
    open=df['Open'].values.flatten(),
    high=df['High'].values.flatten(),
    low=df['Low'].values.flatten(),
    close=df['Close'].values.flatten(),
    increasing=dict(line=dict(color='green')),  # Color for increasing (up) candles
    decreasing=dict(line=dict(color='red'))     # Color for decreasing (down) candles
)])

fig.update_layout(
    title='MSFT Stock Price',
    xaxis_title='Date',
    yaxis_title='Stock Price (USD)',
    yaxis=dict(autorange=True)
)

fig.show()

# %% [markdown]
# ## [ ] Data Preprocessing

# %%
???
# Out:
# Object `?` not found.

# %% [markdown]
# ### Load the data

# %%
import pandas as pd

df_microsoft = pd.read_excel(
    'data/microsoft-prices.xlsx', index_col=0
)

df_microsoft
# Out:
#                           Close        High         Low        Open  \
# Price
# Ticker                     MSFT        MSFT        MSFT        MSFT
# NaN                         NaN         NaN         NaN         NaN
# 1986-03-13 00:00:00    0.097222    0.101563    0.088542    0.088542
# 1986-03-14 00:00:00    0.100694    0.102431    0.097222    0.097222
# 1986-03-17 00:00:00    0.102431    0.103299    0.100694    0.100694
# ...                         ...         ...         ...         ...
# 2024-11-05 00:00:00  411.459991  414.899994  408.079987  408.369995
# 2024-11-06 00:00:00  420.179993  420.450012  410.519989  412.420013
# 2024-11-07 00:00:00  425.429993  426.850006  419.880005  421.279999  19901800
# 2024-11-08 00:00:00  422.540009       426.5  421.779999  425.320007  16875500
#
#                      change_tomorrow
# Price
# 2016-01-05 00:00:00        -1.850139
# 2016-01-06 00:00:00        -3.603606
# 2016-01-07 00:00:00         0.305759
# 2016-01-08 00:00:00        -0.057366
# 2016-01-11 00:00:00         0.909435
# ...                              ...
# 2024-11-04 00:00:00         0.729111
# 2024-11-05 00:00:00         2.075301
# 2024-11-06 00:00:00         1.234046
# 2024-11-07 00:00:00        -0.683955
# 2024-11-08 00:00:00        -0.888284
#
# [2228 rows x 6 columns]

# %% [markdown]
# ### Did the stock go up or down?

# %%
# df_microsoft_linkedin['up_or_down'] = df_microsoft_linkedin['change_tomorrow'].apply(lambda x: "UP" if x > 0 else "DOWN")

import numpy as np
df_microsoft_linkedin['change_tomorrow_direction'] = np.where(df_microsoft_linkedin['change_tomorrow']>0, "UP", "DOWN")
df_microsoft_linkedin.change_tomorrow_direction.value_counts()
# Out:
# change_tomorrow_direction
# UP      1193
# DOWN    1035
# Name: count, dtype: int64

# %%
df_microsoft_linkedin[["Close"]].plot()
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# ## Export preprocessed DataFrame into an Excel

# %% [markdown]
# ## Experimenting with normalizing the columns

# %%
def normalize_column(column):
    try:
        max_val = column.max()
        min_val = column.min()
        abs_max = max(abs(max_val), abs(min_val))
        return column/abs_max
    except:
        return column

# %%
df_normalized = df_microsoft_linkedin.apply(normalize_column)

# %%
df_normalized
# Out:
#                         Close      High       Low      Open    Volume  \
# Price
# 2016-01-05 00:00:00  0.117739  0.118266  0.117427  0.117623  0.255273
# 2016-01-06 00:00:00    0.1156  0.116152  0.115489  0.116317  0.296015
# 2016-01-07 00:00:00  0.111579  0.114209  0.112109  0.112848  0.423698
# 2016-01-08 00:00:00  0.111921  0.113761  0.112281  0.112141   0.36519
# 2016-01-11 00:00:00  0.111857  0.112843  0.110795  0.112441  0.276726
# ...                       ...       ...       ...       ...       ...
# 2024-11-04 00:00:00  0.873599   0.87631  0.873208  0.877516  0.147355
# 2024-11-05 00:00:00  0.880015  0.885876  0.878612  0.874454  0.132027
# 2024-11-06 00:00:00  0.898665  0.897726  0.883865  0.883126  0.199859
# 2024-11-07 00:00:00  0.909894  0.911391  0.904018  0.902098  0.149074
# 2024-11-08 00:00:00  0.903713  0.910644  0.908108  0.910749  0.126405
#
#                      change_tomorrow change_tomorrow_direction
# Price
# 2016-01-05 00:00:00        -0.107025                      DOWN
# 2016-01-06 00:00:00        -0.208458                      DOWN
# 2016-01-07 00:00:00         0.017687                        UP
# 2016-01-08 00:00:00        -0.003318                      DOWN
# 2016-01-11 00:00:00         0.052608                        UP
# ...                              ...                       ...
# 2024-11-04 00:00:00         0.042177                        UP
# 2024-11-05 00:00:00         0.120050                        UP
# 2024-11-06 00:00:00         0.071386                        UP
# 2024-11-07 00:00:00        -0.039565                      DOWN
# 2024-11-08 00:00:00        -0.051385                      DOWN
#
# [2228 rows x 7 columns]

# %%
df_normalized[["change_tomorrow","Volume"]].plot()
# Out:
# <Axes: xlabel='Price'>

# %%
df_microsoft_linkedin.to_excel("./data/microsoft-linkedin-processed.xlsx")
df_normalized.to_excel("./data/microsoft-linkedin-processed-normalized.xlsx")

# %%
ax = df_normalized['Volume'].apply(lambda x:x+1) .plot(label='Volume')
df_normalized['change_tomorrow'].plot(ax=ax, label='Change')
# Out:
# <Axes: xlabel='Price'>
